# %% [markdown]
# <a href="https://colab.research.google.com/github/vatsbalar22/Data-science-tools-openAI/blob/main/mnd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
from datetime import datetime

def get_historical_stock_data(symbol, start_date, end_date):
    stock_data = yf.download(symbol, start=start_date, end=end_date)
    return stock_data

# Example usage:
stock_symbol = "RELIANCE.BO"  # Replace with the desired stock symbol and .BO for BSE or .NS for NSE
start_date = "2000-01-01"  # Replace with the desired start date

# Set end_date to today's date
end_date = datetime.today().strftime('%Y-%m-%d')

historical_data = get_historical_stock_data(stock_symbol, start_date, end_date)

if not historical_data.empty:
    print(historical_data)
else:
    print("Failed to fetch historical data.")
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-04    67.224998    67.224998    67.224998    67.224998    35.767715
# 2000-01-05    68.000000    68.000000    68.000000    68.000000    36.180065
# 2000-01-12    72.750000    72.750000    72.750000    72.750000    38.707348
# 2000-02-07    86.787498    86.787498    86.787498    86.787498    46.176136
# 2000-02-14    90.000000    90.000000    90.000000    90.000000    47.885380
# ...                 ...          ...          ...          ...          ...
# 2024-02-19  2921.350098  2958.800049  2907.550049  2946.149902  2946.149902
# 2024-02-20  2949.899902  2949.899902  2924.000000  2940.750000  2940.750000
# 2024-02-21  2943.850098  2977.000000  2916.149902  2938.199951  2938.199951
# 2024-02-22  2937.949951  2969.100098  2916.000000  2963.350098  2963.350098
# 2024-02-23  2971.399902  2996.149902  2965.250000  2986.350098  2986.350098
#
#             Volume
# Date
# 2000-01-04    6400
# 2000-01-05  418568
# 2000-01-12    4200
# 2000-02-07    8000
# 2000-02-14    2000
# ...            ...
# 2024-02-19  163441
# 2024-02-20  104430
# 2024-02-21  103405
# 2024-02-22  212597
# 2024-02-23  653001
#
# [5808 rows x 6 columns]

# %%
import pandas as pd

df = pd.DataFrame(historical_data)
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-04    67.224998    67.224998    67.224998    67.224998    35.767715
# 2000-01-05    68.000000    68.000000    68.000000    68.000000    36.180065
# 2000-01-12    72.750000    72.750000    72.750000    72.750000    38.707348
# 2000-02-07    86.787498    86.787498    86.787498    86.787498    46.176136
# 2000-02-14    90.000000    90.000000    90.000000    90.000000    47.885380
# ...                 ...          ...          ...          ...          ...
# 2024-02-19  2921.350098  2958.800049  2907.550049  2946.149902  2946.149902
# 2024-02-20  2949.899902  2949.899902  2924.000000  2940.750000  2940.750000
# 2024-02-21  2943.850098  2977.000000  2916.149902  2938.199951  2938.199951
# 2024-02-22  2937.949951  2969.100098  2916.000000  2963.350098  2963.350098
# 2024-02-23  2971.399902  2996.149902  2965.250000  2986.350098  2986.350098
#
#             Volume
# Date
# 2000-01-04    6400
# 2000-01-05  418568
# 2000-01-12    4200
# 2000-02-07    8000
# 2000-02-14    2000
# ...            ...
# 2024-02-19  163441
# 2024-02-20  104430
# 2024-02-21  103405
# 2024-02-22  212597
# 2024-02-23  653001
#
# [5808 rows x 6 columns]

# %%
df.reset_index()
# Out:
#            Date         Open         High          Low        Close  \
# 0    2000-01-04    67.224998    67.224998    67.224998    67.224998
# 1    2000-01-05    68.000000    68.000000    68.000000    68.000000
# 2    2000-01-12    72.750000    72.750000    72.750000    72.750000
# 3    2000-02-07    86.787498    86.787498    86.787498    86.787498
# 4    2000-02-14    90.000000    90.000000    90.000000    90.000000
# ...         ...          ...          ...          ...          ...
# 5803 2024-02-19  2921.350098  2958.800049  2907.550049  2946.149902
# 5804 2024-02-20  2949.899902  2949.899902  2924.000000  2940.750000
# 5805 2024-02-21  2943.850098  2977.000000  2916.149902  2938.199951
# 5806 2024-02-22  2937.949951  2969.100098  2916.000000  2963.350098
# 5807 2024-02-23  2971.399902  2996.149902  2965.250000  2986.350098
#
#         Adj Close  Volume
# 0       35.767715    6400
# 1       36.180065  418568
# 2       38.707348    4200
# 3       46.176136    8000
# 4       47.885380    2000
# ...           ...     ...
# 5803  2946.149902  163441
# 5804  2940.750000  104430
# 5805  2938.199951  103405
# 5806  2963.350098  212597
# 5807  2986.350098  653001
#
# [5808 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df['Close'])

# %%
df['Tommorow']=df['Close'].shift(1)

# %%
df['Target']=(df['Close']>df['Tommorow']).astype(int)

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  Volume  \
# 0 2000-01-04  67.224998  67.224998  67.224998  67.224998  35.767715    6400
# 1 2000-01-05  68.000000  68.000000  68.000000  68.000000  36.180065  418568
# 2 2000-01-12  72.750000  72.750000  72.750000  72.750000  38.707348    4200
# 3 2000-02-07  86.787498  86.787498  86.787498  86.787498  46.176136    8000
# 4 2000-02-14  90.000000  90.000000  90.000000  90.000000  47.885380    2000
#
#     Tommorow  Target
# 0        NaN       0
# 1  67.224998       1
# 2  68.000000       1
# 3  72.750000       1
# 4  86.787498       1

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5808.000000  5808.000000  5808.000000  5808.000000  5808.000000
# mean    754.313591   762.830148   745.236932   753.666255   718.991682
# std     759.929549   767.244877   751.864081   759.242580   771.279545
# min      51.549999    51.549999    51.549999    51.549999    28.786873
# 25%     239.625000   245.115627   235.309380   240.618744   188.666286
# 50%     477.500000   482.712494   471.049988   477.106262   426.479477
# 75%     934.537506   943.025009   923.812500   932.400024   926.328125
# max    2971.399902  2996.149902  2965.250000  2986.350098  2986.350098
#
#              Volume     Tommorow       Target
# count  5.808000e+03  5807.000000  5808.000000
# mean   4.388067e+06   753.281774     0.517734
# std    1.899823e+07   758.742288     0.499728
# min    0.000000e+00    51.549999     0.000000
# 25%    4.820948e+05   240.212494     0.000000
# 50%    1.305329e+06   477.075012     1.000000
# 75%    5.268453e+06   932.175018     1.000000
# max    7.946226e+08  2963.350098     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5808 entries, 0 to 5807
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5808 non-null   datetime64[ns]
#  1   Open       5808 non-null   float64
#  2   High       5808 non-null   float64
#  3   Low        5808 non-null   float64
#  4   Close      5808 non-null   float64
#  5   Adj Close  5808 non-null   float64
#  6   Volume     5808 non-null   int64
#  7   Tommorow   5807 non-null   float64
#  8   Target     5808 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(2)
# memory usage: 408.5 KB

# %%
df.drop(df.columns[[0,4]],axis=1,inplace=True)

# %%
df.head()
# Out:
#         Open       High        Low  Adj Close  Volume   Tommorow  Target
# 0  67.224998  67.224998  67.224998  35.767715    6400        NaN       0
# 1  68.000000  68.000000  68.000000  36.180065  418568  67.224998       1
# 2  72.750000  72.750000  72.750000  38.707348    4200  68.000000       1
# 3  86.787498  86.787498  86.787498  46.176136    8000  72.750000       1
# 4  90.000000  90.000000  90.000000  47.885380    2000  86.787498       1

# %%
df.head()
# Out:
#         Open       High        Low  Adj Close  Volume   Tommorow  Target
# 0  67.224998  67.224998  67.224998  35.767715    6400        NaN       0
# 1  68.000000  68.000000  68.000000  36.180065  418568  67.224998       1
# 2  72.750000  72.750000  72.750000  38.707348    4200  68.000000       1
# 3  86.787498  86.787498  86.787498  46.176136    8000  72.750000       1
# 4  90.000000  90.000000  90.000000  47.885380    2000  86.787498       1

# %%
df.dropna(axis=0 , how='any')
# Out:
#              Open         High          Low    Adj Close  Volume     Tommorow  \
# 1       68.000000    68.000000    68.000000    36.180065  418568    67.224998
# 2       72.750000    72.750000    72.750000    38.707348    4200    68.000000
# 3       86.787498    86.787498    86.787498    46.176136    8000    72.750000
# 4       90.000000    90.000000    90.000000    47.885380    2000    86.787498
# 5       72.724998    72.724998    72.724998    38.694042    2400    90.000000
# ...           ...          ...          ...          ...     ...          ...
# 5803  2921.350098  2958.800049  2907.550049  2946.149902  163441  2921.350098
# 5804  2949.899902  2949.899902  2924.000000  2940.750000  104430  2946.149902
# 5805  2943.850098  2977.000000  2916.149902  2938.199951  103405  2940.750000
# 5806  2937.949951  2969.100098  2916.000000  2963.350098  212597  2938.199951
# 5807  2971.399902  2996.149902  2965.250000  2986.350098  653001  2963.350098
#
#       Target
# 1          1
# 2          1
# 3          1
# 4          1
# 5          0
# ...      ...
# 5803       1
# 5804       0
# 5805       0
# 5806       1
# 5807       1
#
# [5807 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns='Target')
y= df['Target']

# %%
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5803    1
# 5804    0
# 5805    0
# 5806    1
# 5807    1
# Name: Target, Length: 5808, dtype: int64

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2,random_state=42 )

# %%
print("X_train shape:", x_train.shape)
print("X_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (4646, 6)
# X_test shape: (1162, 6)
# y_train shape: (4646,)
# y_test shape: (1162,)

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the scaler with feature_range=(0, 1)
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler on the training data and transform it
X_train_scaled = scaler.fit_transform(x_train)

# Transform the test data using the same scaler
X_test_scaled = scaler.transform(x_test)

# %%
X_train_scaled
# Out:
# array([[3.09416590e-01, 3.13811725e-01, 3.10069671e-01, 3.16573887e-01,
#         4.15270092e-04, 3.09722507e-01],
#        [8.14579543e-01, 8.19618991e-01, 8.16298864e-01, 8.17251420e-01,
#         1.81389253e-04, 8.21227409e-01],
#        [2.09856674e-01, 2.09960609e-01, 2.08823832e-01, 2.09063835e-01,
#         1.46211799e-03, 2.10436832e-01],
#        ...,
#        [8.19716794e-01, 8.30469345e-01, 8.21446958e-01, 8.26575701e-01,
#         3.99452142e-03, 8.17037577e-01],
#        [8.78966415e-01, 8.76978193e-01, 8.56694221e-01, 8.59428195e-01,
#         2.31416776e-04, 8.79043827e-01],
#        [3.37132069e-02, 3.37100129e-02, 3.16436149e-02, 2.42336403e-02,
#         1.92647529e-02, 3.35874729e-02]])

# %%
import numpy as np

# Check for NaN values in X_train_scaled
nan_values = np.isnan(X_train_scaled)
print("Number of NaN values in X_train_scaled:", np.sum(nan_values))
# Out:
# Number of NaN values in X_train_scaled: 1

# %%
from sklearn.impute import SimpleImputer

# Example imputation using mean
imputer = SimpleImputer(strategy='mean')
X_train_imputed = imputer.fit_transform(X_train_scaled)

# %%
model.fit(X_train_imputed, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
prediction = model.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test ,prediction )

# %%
accuracy
# Out:
# 0.6015490533562823

# %%
x_new  = [[2949.899902	,2949.899902,	2924.000000	,2940.750000	,104430	,2946.149902]]
x_new_scaled = scaler.transform(x_new)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
x_new_scaled
# Out:
# array([[9.92636608e-01, 9.84293282e-01, 9.85842743e-01, 9.84581869e-01,
#         1.31420878e-04, 9.94092934e-01]])

# %%
next_day_high = model.predict(x_new_scaled)

# %%
next_day_high
# Out:
# array([1])
