# %% [markdown]
# <a href="https://colab.research.google.com/github/vatsbalar22/Data-science-tools-openAI/blob/main/mnd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
from datetime import datetime

def get_historical_stock_data(symbol, start_date, end_date):
    stock_data = yf.download(symbol, start=start_date, end=end_date)
    return stock_data

# Example usage:
stock_symbol = "PAYTM.BO"  # Replace with the desired stock symbol and .BO for BSE or .NS for NSE
start_date = "2000-01-01"  # Replace with the desired start date

# Set end_date to today's date
end_date = datetime.today().strftime('%Y-%m-%d')

historical_data = get_historical_stock_data(stock_symbol, start_date, end_date)

if not historical_data.empty:
    print(historical_data)
else:
    print("Failed to fetch historical data.")
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-11-18  1955.000000  1961.050049  1564.000000  1564.150024  1564.150024
# 2021-11-22  1500.000000  1518.150024  1271.250000  1360.300049  1360.300049
# 2021-11-23  1358.000000  1525.000000  1358.000000  1494.949951  1494.949951
# 2021-11-24  1504.000000  1790.000000  1503.300049  1753.150024  1753.150024
# 2021-11-25  1768.000000  1875.000000  1710.849976  1796.550049  1796.550049
# ...                 ...          ...          ...          ...          ...
# 2024-02-19   358.549988   358.549988   358.549988   358.549988   358.549988
# 2024-02-20   376.450012   376.450012   376.450012   376.450012   376.450012
# 2024-02-21   395.250000   395.250000   395.250000   395.250000   395.250000
# 2024-02-22   403.250000   403.250000   380.450012   388.200012   388.200012
# ...

# %%
import pandas as pd

df = pd.DataFrame(historical_data)
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-11-18  1955.000000  1961.050049  1564.000000  1564.150024  1564.150024
# 2021-11-22  1500.000000  1518.150024  1271.250000  1360.300049  1360.300049
# 2021-11-23  1358.000000  1525.000000  1358.000000  1494.949951  1494.949951
# 2021-11-24  1504.000000  1790.000000  1503.300049  1753.150024  1753.150024
# 2021-11-25  1768.000000  1875.000000  1710.849976  1796.550049  1796.550049
# ...                 ...          ...          ...          ...          ...
# 2024-02-19   358.549988   358.549988   358.549988   358.549988   358.549988
# 2024-02-20   376.450012   376.450012   376.450012   376.450012   376.450012
# 2024-02-21   395.250000   395.250000   395.250000   395.250000   395.250000
# 2024-02-22   403.250000   403.250000   380.450012   388.200012   388.200012
# 2024-02-23   395.000000   407.600006   385.149994   407.600006   407.600006
#
#              Volume
# Date
# 2021-11-18  1006207
# ...

# %%
df.reset_index()
# Out:
#           Date         Open         High          Low        Close  \
# 0   2021-11-18  1955.000000  1961.050049  1564.000000  1564.150024
# 1   2021-11-22  1500.000000  1518.150024  1271.250000  1360.300049
# 2   2021-11-23  1358.000000  1525.000000  1358.000000  1494.949951
# 3   2021-11-24  1504.000000  1790.000000  1503.300049  1753.150024
# 4   2021-11-25  1768.000000  1875.000000  1710.849976  1796.550049
# ..         ...          ...          ...          ...          ...
# 539 2024-02-19   358.549988   358.549988   358.549988   358.549988
# 540 2024-02-20   376.450012   376.450012   376.450012   376.450012
# 541 2024-02-21   395.250000   395.250000   395.250000   395.250000
# 542 2024-02-22   403.250000   403.250000   380.450012   388.200012
# 543 2024-02-23   395.000000   407.600006   385.149994   407.600006
#
#        Adj Close   Volume
# 0    1564.150024  1006207
# 1    1360.300049  1911761
# 2    1494.949951  1116756
# 3    1753.150024  1664157
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(df['Close'])

# %%
df['Tommorow']=df['Close'].shift(1)

# %%
df['Target']=(df['Close']>df['Tommorow']).astype(int)

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#         Date    Open         High          Low        Close    Adj Close  \
# 0 2021-11-18  1955.0  1961.050049  1564.000000  1564.150024  1564.150024
# 1 2021-11-22  1500.0  1518.150024  1271.250000  1360.300049  1360.300049
# 2 2021-11-23  1358.0  1525.000000  1358.000000  1494.949951  1494.949951
# 3 2021-11-24  1504.0  1790.000000  1503.300049  1753.150024  1753.150024
# 4 2021-11-25  1768.0  1875.000000  1710.849976  1796.550049  1796.550049
#
#     Volume     Tommorow  Target
# 0  1006207          NaN       0
# 1  1911761  1564.150024       0
# 2  1116756  1360.300049       1
# 3  1664157  1494.949951       1
# 4  1230370  1753.150024       1

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   544.000000   544.000000   544.000000   544.000000   544.000000
# mean    758.383457   773.310754   741.499908   754.659559   754.659559
# std     245.197860   250.814913   234.555291   240.084908   240.084908
# min     318.750000   338.399994   318.350006   325.250000   325.250000
# 25%     619.000000   632.912491   604.112518   616.487503   616.487503
# 50%     698.924988   714.800018   685.300018   698.125000   698.125000
# 75%     856.074997   867.962509   847.574997   854.399979   854.399979
# max    1955.000000  1961.050049  1710.849976  1796.550049  1796.550049
#
#              Volume     Tommorow      Target
# count  5.440000e+02   543.000000  544.000000
# mean   4.086848e+05   755.298711    0.459559
# std    1.140505e+06   239.842592    0.498821
# min    9.918000e+03   325.250000    0.000000
# 25%    9.987275e+04   616.575012    0.000000
# 50%    1.845335e+05   698.400024    0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       544 non-null    datetime64[ns]
#  1   Open       544 non-null    float64
#  2   High       544 non-null    float64
#  3   Low        544 non-null    float64
#  4   Close      544 non-null    float64
#  5   Adj Close  544 non-null    float64
#  6   Volume     544 non-null    int64
#  7   Tommorow   543 non-null    float64
#  8   Target     544 non-null    int64
# dtypes: datetime64[ns](1), float64(6), int64(2)
# memory usage: 38.4 KB

# %%
df.drop(df.columns[[0,4]],axis=1,inplace=True)

# %%
df.head()
# Out:
#      Open         High          Low    Adj Close   Volume     Tommorow  Target
# 0  1955.0  1961.050049  1564.000000  1564.150024  1006207          NaN       0
# 1  1500.0  1518.150024  1271.250000  1360.300049  1911761  1564.150024       0
# 2  1358.0  1525.000000  1358.000000  1494.949951  1116756  1360.300049       1
# 3  1504.0  1790.000000  1503.300049  1753.150024  1664157  1494.949951       1
# 4  1768.0  1875.000000  1710.849976  1796.550049  1230370  1753.150024       1

# %%
df.head()
# Out:
#      Open         High          Low    Adj Close   Volume     Tommorow  Target
# 0  1955.0  1961.050049  1564.000000  1564.150024  1006207          NaN       0
# 1  1500.0  1518.150024  1271.250000  1360.300049  1911761  1564.150024       0
# 2  1358.0  1525.000000  1358.000000  1494.949951  1116756  1360.300049       1
# 3  1504.0  1790.000000  1503.300049  1753.150024  1664157  1494.949951       1
# 4  1768.0  1875.000000  1710.849976  1796.550049  1230370  1753.150024       1

# %%
df.dropna(axis=0 , how='any')
# Out:
#             Open         High          Low    Adj Close   Volume     Tommorow  \
# 1    1500.000000  1518.150024  1271.250000  1360.300049  1911761  1564.150024
# 2    1358.000000  1525.000000  1358.000000  1494.949951  1116756  1360.300049
# 3    1504.000000  1790.000000  1503.300049  1753.150024  1664157  1494.949951
# 4    1768.000000  1875.000000  1710.849976  1796.550049  1230370  1753.150024
# 5    1777.000000  1832.000000  1661.099976  1781.150024   412981  1796.550049
# ..           ...          ...          ...          ...      ...          ...
# 539   358.549988   358.549988   358.549988   358.549988   112836   341.500000
# 540   376.450012   376.450012   376.450012   376.450012   124664   358.549988
# 541   395.250000   395.250000   395.250000   395.250000   176831   376.450012
# 542   403.250000   403.250000   380.450012   388.200012  2111252   395.250000
# 543   395.000000   407.600006   385.149994   407.600006   404960   388.200012
#
#      Target
# 1         0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns='Target')
y= df['Target']

# %%
y
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 539    1
# 540    1
# 541    1
# 542    0
# 543    1
# Name: Target, Length: 544, dtype: int64

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2,random_state=42 )

# %%
print("X_train shape:", x_train.shape)
print("X_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (435, 6)
# X_test shape: (109, 6)
# y_train shape: (435,)
# y_test shape: (109,)

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the scaler with feature_range=(0, 1)
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler on the training data and transform it
X_train_scaled = scaler.fit_transform(x_train)

# Transform the test data using the same scaler
X_test_scaled = scaler.transform(x_test)

# %%
X_train_scaled
# Out:
# array([[0.25390022, 0.23099699, 0.23910233, 0.22565078, 0.00225947,
#         0.24957521],
#        [0.32515003, 0.29578292, 0.32236984, 0.30354106, 0.00562844,
#         0.31346428],
#        [0.26634667, 0.25013016, 0.2778456 , 0.26799427, 0.00789095,
#         0.25946441],
#        ...,
#        [0.1368421 , 0.11971234, 0.13382406, 0.12319037, 0.01138366,
#         0.13046286],
#        [0.37785016, 0.35096968, 0.36409334, 0.34870521, 0.01246363,
#         0.36681846],
#        [0.23264187, 0.2185995 , 0.22886893, 0.21365457, 0.01400515,
#         0.22384963]])

# %%
import numpy as np

# Check for NaN values in X_train_scaled
nan_values = np.isnan(X_train_scaled)
print("Number of NaN values in X_train_scaled:", np.sum(nan_values))
# Out:
# Number of NaN values in X_train_scaled: 0

# %%
from sklearn.impute import SimpleImputer

# Example imputation using mean
imputer = SimpleImputer(strategy='mean')
X_train_imputed = imputer.fit_transform(X_train_scaled)

# %%
model.fit(X_train_imputed, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
imputer = SimpleImputer(strategy='mean')
X_test_imputed = imputer.fit_transform(X_test_scaled)

# %%
prediction = model.predict(X_test_imputed)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test ,prediction )

# %%
accuracy
# Out:
# 0.6238532110091743

# %%
# Extract the last row of the DataFrame
last_row = df.iloc[-1]

# Extract the relevant features (excluding 'High') and reshape into the format expected by your model
# X_new = np.array([[937.70, 918.70, 937.70, 924.45, 380102.0]])
X_new = last_row[['Open', 'High','Low', 'Adj Close', 'Volume','Tommorow']].values.reshape(1, -1)

# Scale the new feature data using the same scaler used for training
X_new_scaled = scaler.transform(X_new)

# Predict the next day's high price
next_day_high = model.predict(X_new_scaled)

print("Predicted next day's price:", next_day_high)
# Out:
# Predicted next day's price: [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
x_new
# Out:
# [[1504.0, 1790.0, 1503.300049, 1753.150024, 1664157, 1494.949951]]

# %%
x_new  = [[1504.000000,	1790.000000	,1503.300049,	1753.150024,	1664157,	1494.949951]]
x_new_scaled = scaler.transform(x_new)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
x_new_scaled
# Out:
# array([[0.8127893 , 0.94468307, 0.85095158, 0.97050226, 0.0717976 ,
#         0.79501115]])

# %%
next_day_high = model.predict(x_new_scaled)

# %%
next_day_high
# Out:
# array([0])
