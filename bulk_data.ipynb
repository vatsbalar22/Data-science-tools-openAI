# %% [markdown]
# <a href="https://colab.research.google.com/github/vatsbalar22/Data-science-tools-openAI/blob/main/bulk_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nselib

# %%
import nselib
from nselib import capital_market

# %%
nselib.trading_holiday_calendar()
# Out:
#                                    Product  tradingDate  ...                           description Sr_no
# 0                          Corporate Bonds  22-Jan-2024  ...                     Special Holiday\r     1
# 1                          Corporate Bonds  26-Jan-2024  ...                        Republic Day\r     2
# 2                          Corporate Bonds  19-Feb-2024  ...  Chatrapati Shivaji Maharaj Jayanti\r     3
# 3                          Corporate Bonds  08-Mar-2024  ...                       Mahashivratri\r     4
# 4                          Corporate Bonds  25-Mar-2024  ...                                Holi\r     5
# ..                                     ...          ...  ...                                   ...   ...
# 15  Securities Lending & Borrowing Schemes  12-Oct-2024  ...                            Dussehra\r    16
# 16  Securities Lending & Borrowing Schemes  01-Nov-2024  ...                 Diwali Laxmi Pujan*\r    17
# ...

# %%
capital_market.bhav_copy_equities('22-12-2023')
# Out:
#           SYMBOL SERIES     OPEN     HIGH  ...  TOTTRDQTY     TOTTRDVAL    TIMESTAMP  TOTALTRADES
# 0     1018GS2026     GS   118.76   125.00  ...       4923  5.957498e+05  22-DEC-2023           17
# 1     182D080224     TB    99.10    99.10  ...        200  1.982000e+04  22-DEC-2023            1
# 2     182D090524     TB    97.14    97.24  ...        900  8.746200e+04  22-DEC-2023            4
# 3     182D110424     TB    97.80    97.80  ...      20000  1.956000e+06  22-DEC-2023            2
# 4     182D130624     TB    96.46    96.75  ...       2100  2.026650e+05  22-DEC-2023            7
# ...          ...    ...      ...      ...  ...        ...           ...          ...          ...
# 2600        ZOTA     EQ   476.25   494.80  ...      34377  1.664444e+07  22-DEC-2023         2812
# 2601       ZUARI     EQ   175.80   193.20  ...    1779435  3.355185e+08  22-DEC-2023        38294
# 2602    ZUARIIND     EQ   199.00   206.90  ...     287332  5.808386e+07  22-DEC-2023         5089
# ...

# %%
capital_market.block_deals_data(period='1m')
# Out:
#     Date    Symbol               SecurityName  ... TradePrice/Wght.Avg.Price Remarks    ï»¿"Date"
# 0    NaN  INFIBEAM   Infibeam Avenues Limited  ...                     34.90       -  29-JAN-2024
# 1    NaN  INFIBEAM   Infibeam Avenues Limited  ...                     34.90       -  29-JAN-2024
# 2    NaN  INFIBEAM   Infibeam Avenues Limited  ...                     35.55       -  31-JAN-2024
# 3    NaN  INFIBEAM   Infibeam Avenues Limited  ...                     35.55       -  31-JAN-2024
# 4    NaN  INFIBEAM   Infibeam Avenues Limited  ...                     38.00       -  02-FEB-2024
# ..   ...       ...                        ...  ...                       ...     ...          ...
# 131  NaN   DEVYANI  Devyani International Ltd  ...                    164.10       -  21-FEB-2024
# 132  NaN   DEVYANI  Devyani International Ltd  ...                    164.10       -  21-FEB-2024
# 133  NaN   DEVYANI  Devyani International Ltd  ...                    164.10       -  21-FEB-2024
# ...

# %%
capital_market.bulk_deal_data(period='1m')
# Out:
#      Date    Symbol               SecurityName  ... TradePrice/Wght.Avg.Price Remarks    ï»¿"Date"
# 0     NaN      AGNI       Agni Green Power Ltd  ...                     57.50       -  29-JAN-2024
# 1     NaN      AGNI       Agni Green Power Ltd  ...                     57.50       -  29-JAN-2024
# 2     NaN      AGNI       Agni Green Power Ltd  ...                     57.50       -  29-JAN-2024
# 3     NaN      AGNI       Agni Green Power Ltd  ...                     57.49       -  29-JAN-2024
# 4     NaN      AGNI       Agni Green Power Ltd  ...                     57.50       -  29-JAN-2024
# ...   ...       ...                        ...  ...                       ...     ...          ...
# 2538  NaN    WTICAB  Wise Travel India Limited  ...                    210.58       -  23-FEB-2024
# 2539  NaN  ZUARIIND   Zuari Industries Limited  ...                    334.40       -  23-FEB-2024
# ...
